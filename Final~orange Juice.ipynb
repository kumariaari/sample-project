# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\A Ramesh\Desktop\Digital nest 1\Machine Learning\Worksheet in CPG - Orange Juice~log.csv")

# %%
df.head()
# Out:
#      yr  Wk  own_brand_tv_grp  basepricepergal  Log price  top3pctbvap   temp  \
# 0  2006   1              73.0             4.95   0.694605         0.29  34.67
# 1  2006   2              45.0             5.02   0.700704         0.37  33.66
# 2  2006   3              40.0             5.07   0.705008         0.38  30.73
# 3  2006   4              52.0             5.09   0.706718         0.41  34.68
# 4  2006   5              45.0             5.12   0.709270         0.39  31.22
#
#    gasprice  brand1tv  brand2tv  xmaswkind  easterwkind  nywkind    ojvol  \
# 0     233.2      0.11      0.19          0            0        1  3753938
# 1     226.3      0.15      0.15          0            0        0  3530670
# 2     228.2      0.19      0.34          0            0        0  3575088
# 3     231.4      0.15      0.30          0            0        0  3453849
# 4     228.0      0.20      0.43          0            0        0  3432755
#
#    log ojvol
# 0   6.574487
# 1   6.547857
# ...

# %%
df.shape
# Out:
# (196, 15)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.dtypes
# Out:
# yr                    int64
# Wk                    int64
# own_brand_tv_grp    float64
# basepricepergal     float64
# Log price           float64
# top3pctbvap         float64
# temp                float64
# gasprice            float64
# brand1tv            float64
# brand2tv            float64
# xmaswkind             int64
# easterwkind           int64
# nywkind               int64
# ojvol                 int64
# log ojvol           float64
# dtype: object

# %%
df.describe()
# Out:
#                 yr          Wk  own_brand_tv_grp  basepricepergal   Log price  \
# count   196.000000  196.000000        196.000000       196.000000  196.000000
# mean   2007.408163   25.275510         31.370396         5.960255    0.774178
# std       1.089217   14.608589         25.924055         0.412647    0.031172
# min    2006.000000    1.000000          0.000000         4.950000    0.694605
# 25%    2006.000000   13.000000          0.675000         5.590000    0.747412
# 50%    2007.000000   25.000000         42.000000         6.170000    0.790285
# 75%    2008.000000   37.000000         52.075000         6.272500    0.797441
# max    2009.000000   52.000000         84.000000         6.350000    0.802774
#
#        top3pctbvap        temp    gasprice    brand1tv    brand2tv  \
# count   196.000000  196.000000  196.000000  196.000000  196.000000
# mean      0.321276   48.722041  271.108163    0.167959    0.155357
# ...

# %%
df.corr()
# Out:
#                         yr        Wk  own_brand_tv_grp  basepricepergal  \
# yr                1.000000 -0.123127         -0.264526         0.697924
# Wk               -0.123127  1.000000          0.017146         0.101333
# own_brand_tv_grp -0.264526  0.017146          1.000000        -0.250171
# basepricepergal   0.697924  0.101333         -0.250171         1.000000
# Log price         0.701209  0.107317         -0.250995         0.999710
# top3pctbvap      -0.124201 -0.182643          0.075405        -0.497571
# temp             -0.006748  0.310287          0.131225        -0.009466
# gasprice         -0.027208  0.062824         -0.004499         0.316802
# brand1tv          0.160844 -0.034831         -0.063741         0.045629
# brand2tv         -0.330233 -0.304444          0.123222        -0.190387
# xmaswkind        -0.046839  0.220106          0.031965         0.013049
# easterwkind       0.012201 -0.111691          0.003096         0.000787
# ...

# %% [markdown]
# # Plots

# %%
df.plot.scatter('own_brand_tv_grp','ojvol')

# %%
df.plot.scatter('basepricepergal','ojvol');

# %%
df.plot.scatter('temp','ojvol');

# %%
df.plot.scatter('gasprice','ojvol');

# %%
df.plot.scatter('brand1tv','ojvol');

# %%
df.plot.scatter('brand2tv','ojvol');

# %%
df.plot.scatter('brand1tv','own_brand_tv_grp');

# %%
df.plot.scatter('brand2tv','own_brand_tv_grp');

# %%
df.plot.scatter('yr','ojvol')

# %%
df.plot.scatter('Wk','ojvol')

# %%
df.plot.scatter('xmaswkind','ojvol')

# %%
df.plot.scatter('easterwkind','ojvol')

# %%
df.plot.scatter('nywkind','ojvol')

# %% [markdown]
# # Outlier Treatment

# %%
df['ojvol'].plot.box()

# %%
df1=df[df['ojvol']<3750000]

# %%
df1['ojvol'].plot.box()

# %%
Var_Corr = df1.corr()
plt.figure(figsize=(10,9))
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)

# %%
df1.drop(['basepricepergal','ojvol'], axis=1)
# Out:
#        yr  Wk  own_brand_tv_grp  Log price  top3pctbvap   temp  gasprice  \
# 1    2006   2              45.0   0.700704         0.37  33.66     226.3
# 2    2006   3              40.0   0.705008         0.38  30.73     228.2
# 3    2006   4              52.0   0.706718         0.41  34.68     231.4
# 4    2006   5              45.0   0.709270         0.39  31.22     228.0
# 5    2006   6              55.0   0.711807         0.35  23.96     218.9
# 6    2006   7              42.0   0.714330         0.36  19.84     216.7
# 7    2006   8              51.0   0.713491         0.39  25.92     225.9
# 8    2006   9              42.0   0.713491         0.38  32.49     237.9
# 9    2006  10              51.0   0.713491         0.42  40.38     238.5
# 10   2006  11               1.0   0.714330         0.40  32.59     250.1
# 11   2006  12               0.0   0.714330         0.36  32.04     247.1
# 12   2006  13              59.0   0.714330         0.34  45.39     257.6
# ...

# %%
x = df1['Wk']
y = df1['ojvol']
plt.plot(x,y)
plt.show()

# %%
from sklearn.preprocessing import scale

# %%
df1_scale=scale(df1[['ojvol']])
# Out:
# C:\Users\A Ramesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
x_train, x_test = train_test_split(df1, test_size=0.2, random_state = 10)

# %%
x_train=df1.drop('ojvol', axis=1)
y_train=df1['ojvol']

# %%
x_test=df1.drop('ojvol',axis=1)
y_test=df1['ojvol']

# %%
from sklearn.linear_model import LinearRegression

# %%
lreg=LinearRegression()

# %%
lreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred=lreg.predict(x_test)

# %%
lreg.score(x_test,y_test)
# Out:
# 0.99746412570011

# %%
lreg.score(x_train,y_train)
# Out:
# 0.99746412570011

# %%
RMSE_test=np.sqrt(np.mean(np.power((np.array(y_test)-np.array(pred)),2)))
RMSE_test
# Out:
# 14900.407120361218

# %%
RMSE_Train=np.sqrt(np.mean(np.power((np.array(y_train)-np.array(lreg.predict(x_train))),2)))
RMSE_Train
# Out:
# 14900.407120361218

# %%
predictions = lreg.predict(x_test)

# %%
plt.scatter(y_test,predictions)
